# %% [markdown]
# <a href="https://colab.research.google.com/github/ramafadilah17/ramafadilah17.github.io/blob/main/Hands-On%20Python%20-%20Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction to Probability and Statistics
# ## Assignment
#
# In this assignment, we will use the dataset of diabetes patients taken [from here](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mlb
import plotly.express as px
import random

import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt",sep='\t')
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %% [markdown]
# In this dataset, columns as the following:
# * Age and sex are self-explanatory
# * BMI is body mass index
# * BP is average blood pressure
# * S1 through S6 are different blood measurements
# * Y is the qualitative measure of disease progression over one year
#
# Let's study this dataset using methods of probability and statistics.
#
# ### Task 1: Compute mean values and variance for all values

# %%
df.mean()
# Out:
# AGE     48.518100
# SEX      1.468326
# BMI     26.375792
# BP      94.647014
# S1     189.140271
# S2     115.439140
# S3      49.788462
# S4       4.070249
# S5       4.641411
# S6      91.260181
# Y      152.133484
# dtype: float64

# %%
np.mean(df.AGE)
# Out:
# 48.51809954751131

# %%
df.var()
# Out:
# AGE     171.846610
# SEX       0.249561
# BMI      19.519798
# BP      191.304401
# S1     1197.717241
# S2      924.955494
# S3      167.293585
# S4        1.665261
# S5        0.272892
# S6      132.165712
# Y      5943.331348
# dtype: float64

# %% [markdown]
# ### Task 2: Plot boxplots for BMI, BP and Y depending on gender

# %%
sns.set(style="darkgrid")
sns.boxplot(x = 'BMI', y = 'SEX', data=df, orient = 'h')
# Out:
# <Axes: xlabel='BMI', ylabel='SEX'>

# %%
sns.set(style="darkgrid")
sns.boxplot(x = 'BP', y = 'SEX', data=df, orient = 'h')
# Out:
# <Axes: xlabel='BP', ylabel='SEX'>

# %%
sns.set(style="darkgrid")
sns.boxplot(x = 'Y', y = 'SEX', data=df, orient = 'h')
# Out:
# <Axes: xlabel='Y', ylabel='SEX'>

# %% [markdown]
# ### Task 3: What is the the distribution of Age, Sex, BMI and Y variables?

# %%
df['AGE'].hist(bins=15)
plt.suptitle('AGE distribution of diabetes patients')
plt.xlabel('AGE')
plt.ylabel('Count')
plt.show()

sns.set(style="darkgrid")
sns.kdeplot(data=df['AGE'], shade = True)
plt.show()

# %%
df['SEX'].hist(bins=15)
plt.suptitle('SEX distribution of diabetes patients')
plt.xlabel('SEX')
plt.ylabel('Count')
plt.show()

sns.set(style="darkgrid")
sns.kdeplot(data=df['SEX'], shade = True)
plt.show()

# %%
df['BMI'].hist(bins=15)
plt.suptitle('BMI distribution of diabetes patients')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()

sns.set(style="darkgrid")
sns.kdeplot(data=df['BMI'], shade = True)
plt.show()

# %%
df['Y'].hist(bins=15)
plt.suptitle('Y distribution of diabetes patients')
plt.xlabel('Y')
plt.ylabel('Count')
plt.show()

sns.set(style="darkgrid")
sns.kdeplot(data=df['Y'], shade = True)
plt.show()
