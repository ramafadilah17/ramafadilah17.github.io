# %% [markdown]
# <a href="https://colab.research.google.com/github/ramafadilah17/ramafadilah17.github.io/blob/main/Topik_7_8_%5BFadilah_Ramadhan%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mlb
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # **1.barplot**

# %%
# vertical
sns.set_style("darkgrid")
plt.figure(figsize = (2,4))
sns.countplot(x = 'Sex', data = df, palette = 'Set2')
plt.show()

# %%
# horizontal
sns.set_style("darkgrid")
plt.figure(figsize = (4,2))
sns.countplot(y = 'Sex', data = df, palette = 'Set2')
plt.show()

# %% [markdown]
# # **2. Distplot**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df = df.dropna(subset=['Age'])

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %%
titanic=sns.load_dataset('titanic')
age=titanic['age'].dropna()
sns.distplot(age)
plt.show()

# %% [markdown]
# # **3. boxplot**

# %%
plt.figure(figsize = (3, 6))
sns.boxplot(y = 'Age', data = df, orient = 'h')
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# # **4. scatterplot**

# %%
sns.scatterplot(x = 'Fare', y = 'Age', data = df)
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %% [markdown]
# # **5. piechart**

# %%
male_count = len(df[df['Sex'] == 'male'])
female_count = len(df[df['Sex'] == 'female'])

labels = ['male', 'female']
sizes = [male_count, female_count]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')

plt.show()

# %%
# target variabel dari permasalahan topic ini adalah mengetahui penumpang yang selamat dan yang tidak selamat dengan melihat beberapa data yang sudah di sediakan di dataframe seperti gender, umur, dan lain lain
